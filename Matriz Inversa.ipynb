# %% [markdown]
# # Rafael Nunes Santana - 201800215
#
# ### Atividade 3 - Pesquisa Operacional I
#
# Nessa atividade vamos implementar o algorítimo de eliminação de Gauss-Jordan para calcular a inversa de uma matriz e compará-lo com o algorítimo implementado no numpy (numpy.linalg.inv())

# %%
import numpy as np
import numpy.matlib
from random import randrange

# %%
def inversa(matriz: np.matrix) -> np.matrix:
    # Pegando as dimensões da matriz e verificando se ela é quadrada
    linhas, colunas = matriz.shape
    
    if linhas != colunas:
        raise Exception("Somente matrizes quadradas são invertíveis! Shape da matriz: {} x {}".format(linhas, colunas))
    
    # pegando o tipo dos elementos da matriz
    dtype = matriz.dtype
    
    # alocando a matriz que irá conter uma cópia da matriz original no lado esquerdo (que se tornará a identidade) 
    # e a matriz identidade de tamanho linhas x linhas no lado direito (que se tornará a matriz inversa)
    mat = np.empty([linhas, colunas * 2], dtype=dtype)
    mat[0:linhas, 0:colunas] = matriz
    mat[0:linhas, colunas:colunas * 2] = np.matrix(np.identity(linhas, dtype=dtype))

    for i in range(0, linhas):
    
        # transformando o elemento da diagonal princial em 1 da matriz do lado esquerdo
        if mat[i, i] != 1:
            mat[i] /= mat[i, i]
    
        # transformando os elementos das linhas restantes da matriz do lado esquerdo em 0
        for k in range(0, linhas):
            # não realizamos essa operação na digonal principal (deve ser 1 e não 0)
            if i == k:
                continue
        
            # zerando o elemento k x i
            mat[k] -= mat[i] * mat[k, i] / mat[i, i]
        
    # retornando a matriz do lado direito (que se tornou a inversa)
    return mat[0:linhas, colunas:colunas * 2]

# %%
# testando com o exemplo da atividade e comparando com a função do numpy
matriz = np.mat([[1., 1., 1.], [2., 1., 4.], [2., 3., 5.]])

# função de utilidade
def compara_com_numpy(matriz: np.matrix) -> None:  
    inversa_manual = inversa(matriz)
    inversa_numpy = np.linalg.inv(matriz)

    print("Inversa com o algórítmo implementado:\n", inversa_manual, "\n")
    print("Inversa com o algórítmo do numpy:\n", inversa_numpy, "\n")
    
    print("Multiplicando nossa inversa pela matriz tentando obter a identidade:\n", inversa_manual.dot(matriz), "\n")
    
compara_com_numpy(matriz)
# Out:
# Inversa com o algórítmo implementado:
#  [[ 1.4  0.4 -0.6]
#  [ 0.4 -0.6  0.4]
#  [-0.8  0.2  0.2]]
#
# Inversa com o algórítmo do numpy:
#  [[ 1.4  0.4 -0.6]
#  [ 0.4 -0.6  0.4]
#  [-0.8  0.2  0.2]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00  0.00000000e+00 -4.44089210e-16]
#  [ 0.00000000e+00  1.00000000e+00  1.11022302e-16]
#  [ 0.00000000e+00 -5.55111512e-17  1.00000000e+00]]

# %% [markdown]
# Vamos testar com mais algumas matrizes aleatórias:

# %%
for _ in range (0, 20):
    # sorteando um tamanho entre 2 e 5
    tamanho = randrange(2, 6)
    
    # gerando uma matriz de float64 aleatória
    rand_matrix = np.matlib.randn((tamanho, tamanho))
    
    compara_com_numpy(rand_matrix)
# Out:
# Inversa com o algórítmo implementado:
#  [[-0.03971995 -1.6694503 ]
#  [ 0.82818135 -1.77702939]]
#
# Inversa com o algórítmo do numpy:
#  [[-0.03971995 -1.6694503 ]
#  [ 0.82818135 -1.77702939]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[1.00000000e+00 8.51127316e-17]
#  [2.26681064e-17 1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[  1.84514917   0.84693721  -0.74898186   0.24501237  -4.2178017 ]
#  [ -3.17155932  -1.67562565   0.94934699  -0.59744898   5.85074803]
#  [  1.28924795   0.76818455  -0.06430097   0.51117246  -2.75925621]
#  [  8.85866687   4.39939872  -2.35308062  -1.1985482  -12.7300376 ]
#  [  4.27567377   1.67912656  -0.91671061  -0.59523616  -5.49712349]]
#
# Inversa com o algórítmo do numpy:
#  [[  1.84514917   0.84693721  -0.74898186   0.24501237  -4.2178017 ]
#  [ -3.17155932  -1.67562565   0.94934699  -0.59744898   5.85074803]
#  [  1.28924795   0.76818455  -0.06430097   0.51117246  -2.75925621]
#  [  8.85866687   4.39939872  -2.35308062  -1.1985482  -12.7300376 ]
#  [  4.27567377   1.67912656  -0.91671061  -0.59523616  -5.49712349]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00  1.06337185e-15 -3.42549946e-16  9.87303632e-17
#    9.67500220e-16]
#  [ 4.65670233e-16  1.00000000e+00 -1.18121153e-16 -2.73339884e-16
#   -2.08974083e-15]
#  [-3.57161183e-17  1.75651716e-16  1.00000000e+00 -6.20387462e-17
#    4.61943326e-16]
#  [ 6.34123125e-16  2.20012213e-15  1.58298137e-17  1.00000000e+00
#    9.89513115e-15]
#  [ 5.71960316e-16 -4.34538661e-17 -4.83034526e-16  3.88180805e-16
#    1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[-1.36646449  0.52838949]
#  [-1.53560562 -0.94982067]]
#
# Inversa com o algórítmo do numpy:
#  [[-1.36646449  0.52838949]
#  [-1.53560562 -0.94982067]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00  2.45870501e-17]
#  [-7.03269813e-17  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[-0.83554476 -1.10975799]
#  [-1.94385894 -0.37183197]]
#
# Inversa com o algórítmo do numpy:
#  [[-0.83554476 -1.10975799]
#  [-1.94385894 -0.37183197]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00 -1.74057636e-17]
#  [ 7.19961742e-18  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 0.49167516 -0.57508194  0.54089126  0.04645028 -0.14220191]
#  [ 0.03010049 -0.27380238  0.2864589   0.10724009  0.60734672]
#  [ 0.02936112 -0.52773102  0.33522952 -0.40492365  0.20116679]
#  [ 0.12242279  0.30688166 -0.86008558 -0.13263079  0.04622613]
#  [ 0.11765697 -0.20199374  0.74959884 -1.07886402  0.26213442]]
#
# Inversa com o algórítmo do numpy:
#  [[ 0.49167516 -0.57508194  0.54089126  0.04645028 -0.14220191]
#  [ 0.03010049 -0.27380238  0.2864589   0.10724009  0.60734672]
#  [ 0.02936112 -0.52773102  0.33522952 -0.40492365  0.20116679]
#  [ 0.12242279  0.30688166 -0.86008558 -0.13263079  0.04622613]
#  [ 0.11765697 -0.20199374  0.74959884 -1.07886402  0.26213442]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00 -3.19138565e-16  1.35656642e-15  1.25923738e-15
#   -6.41756510e-16]
#  [-4.83144451e-16  1.00000000e+00 -4.84067211e-15  4.78533906e-16
#    1.63136539e-15]
#  [ 2.03799190e-17  4.42596255e-16  1.00000000e+00 -2.77747180e-15
#    1.25365694e-15]
#  [-6.25386898e-18  1.28939336e-16 -7.00138673e-16  1.00000000e+00
#    3.22776408e-16]
#  [-8.47508627e-17  9.63363282e-16 -5.56747221e-15 -5.56924391e-15
#    1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 0.09010839 -2.51019003]
#  [-0.59897926 -1.9159807 ]]
#
# Inversa com o algórítmo do numpy:
#  [[ 0.09010839 -2.51019003]
#  [-0.59897926 -1.9159807 ]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00 -8.47026689e-18]
#  [ 2.82399041e-17  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[-0.40897632 -0.30200739  0.2938785   0.04941631  0.16442535]
#  [-0.19843947 -1.3342708  -0.52326203 -0.57462453 -0.36462579]
#  [ 1.173056   -0.05566114 -0.69031262 -1.8249      0.06700958]
#  [-0.77484043  0.40271157  0.33479821  0.42890366  0.09399436]
#  [ 0.75310769 -0.48859763 -0.90174951 -1.55696601  0.2928993 ]]
#
# Inversa com o algórítmo do numpy:
#  [[-0.40897632 -0.30200739  0.2938785   0.04941631  0.16442535]
#  [-0.19843947 -1.3342708  -0.52326203 -0.57462453 -0.36462579]
#  [ 1.173056   -0.05566114 -0.69031262 -1.8249      0.06700958]
#  [-0.77484043  0.40271157  0.33479821  0.42890366  0.09399436]
#  [ 0.75310769 -0.48859763 -0.90174951 -1.55696601  0.2928993 ]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00 -8.97748377e-17  2.91714906e-16 -2.04026766e-16
#   -1.46048168e-16]
#  [-3.46176681e-16  1.00000000e+00 -3.26432950e-16  1.89978282e-16
#   -2.25948124e-17]
#  [ 4.17461632e-16  1.38997320e-16  1.00000000e+00  2.60510715e-16
#   -7.21377963e-16]
#  [-3.48157070e-17 -4.96107722e-17  1.19239831e-17  1.00000000e+00
#    1.92659058e-16]
#  [ 8.56094641e-16  1.70365152e-16  5.88537296e-16 -1.17424603e-17
#    1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 0.1921094  -0.02442182 -0.13668282 -0.3422662  -0.25025515]
#  [-0.74035925 -0.39281973 -0.68202448 -0.54837299  0.18518532]
#  [ 0.45283434  0.70901147 -0.28856505 -0.20707278 -0.14142542]
#  [ 0.43462964 -0.25886366  0.42419401  0.69268021  0.31926995]
#  [-0.36248548 -0.26950363 -0.36047564  0.34950633 -0.28740065]]
#
# Inversa com o algórítmo do numpy:
#  [[ 0.1921094  -0.02442182 -0.13668282 -0.3422662  -0.25025515]
#  [-0.74035925 -0.39281973 -0.68202448 -0.54837299  0.18518532]
#  [ 0.45283434  0.70901147 -0.28856505 -0.20707278 -0.14142542]
#  [ 0.43462964 -0.25886366  0.42419401  0.69268021  0.31926995]
#  [-0.36248548 -0.26950363 -0.36047564  0.34950633 -0.28740065]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00 -2.49046978e-17 -3.46563965e-16  1.33433660e-16
#   -1.72067017e-16]
#  [-2.93863698e-16  1.00000000e+00 -1.01312193e-15 -6.14546828e-17
#   -5.40548246e-17]
#  [-1.85337308e-16 -4.04114666e-17  1.00000000e+00 -6.39827454e-17
#   -2.43520921e-16]
#  [ 4.53467959e-16  3.19848436e-17  8.74454863e-16  1.00000000e+00
#    2.03041790e-16]
#  [-5.83886529e-17 -1.82212933e-17 -6.32910103e-16  7.20662434e-17
#    1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 1.4553168   1.01572916]
#  [ 1.651987   -0.38101686]]
#
# Inversa com o algórítmo do numpy:
#  [[ 1.4553168   1.01572916]
#  [ 1.651987   -0.38101686]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00  2.13976459e-16]
#  [-3.09764611e-17  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 0.36718007 -0.37020794 -0.29568455]
#  [-0.48813993  0.00930128 -0.38770206]
#  [ 0.15083964  0.19856259 -0.52636333]]
#
# Inversa com o algórítmo do numpy:
#  [[ 0.36718007 -0.37020794 -0.29568455]
#  [-0.48813993  0.00930128 -0.38770206]
#  [ 0.15083964  0.19856259 -0.52636333]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00  4.65256717e-17 -1.42309532e-16]
#  [ 4.17819590e-17  1.00000000e+00  2.81512186e-17]
#  [ 7.42388757e-17 -1.74660313e-16  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 0.63865334  1.48247081  0.2543062  -0.66473851]
#  [-0.36237157  3.02476654  1.70911838 -0.45892484]
#  [ 0.01046545 -0.01210801 -0.07926675  0.46748385]
#  [-0.30032018 -0.82819673 -0.77597119  0.21473951]]
#
# Inversa com o algórítmo do numpy:
#  [[ 0.63865334  1.48247081  0.2543062  -0.66473851]
#  [-0.36237157  3.02476654  1.70911838 -0.45892484]
#  [ 0.01046545 -0.01210801 -0.07926675  0.46748385]
#  [-0.30032018 -0.82819673 -0.77597119  0.21473951]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00  2.44566159e-16 -4.35913658e-16 -1.53377707e-16]
#  [ 8.04226366e-17  1.00000000e+00  2.12793447e-16  5.66987923e-16]
#  [-7.24809737e-17 -5.80846578e-17  1.00000000e+00 -9.02277571e-17]
#  [-1.53833150e-17 -1.53725120e-16  3.19334185e-17  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 0.90957073 -0.08326514  1.06695453]
#  [ 0.18357717  0.63947772 -0.5362187 ]
#  [-0.34348858  0.28711536  0.17855433]]
#
# Inversa com o algórítmo do numpy:
#  [[ 0.90957073 -0.08326514  1.06695453]
#  [ 0.18357717  0.63947772 -0.5362187 ]
#  [-0.34348858  0.28711536  0.17855433]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00  9.23900330e-17 -2.87445843e-17]
#  [-2.02050426e-17  1.00000000e+00  3.49504169e-16]
#  [-1.51235166e-17  2.13168267e-17  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[-1.63332676  0.63787497 -0.36234762 -0.23845879]
#  [ 0.80224992 -0.12550097  0.32970258  0.59972361]
#  [ 1.60427979 -0.62701846  1.13975915 -0.13245625]
#  [-1.66383194  1.10496993 -0.71650262 -0.10722704]]
#
# Inversa com o algórítmo do numpy:
#  [[-1.63332676  0.63787497 -0.36234762 -0.23845879]
#  [ 0.80224992 -0.12550097  0.32970258  0.59972361]
#  [ 1.60427979 -0.62701846  1.13975915 -0.13245625]
#  [-1.66383194  1.10496993 -0.71650262 -0.10722704]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00 -1.85500517e-16  3.12885275e-16  1.37360419e-15]
#  [ 3.36821850e-15  1.00000000e+00 -1.12653133e-15 -3.60492375e-15]
#  [-1.26485438e-16 -2.98467181e-18  1.00000000e+00  6.02957266e-16]
#  [-5.06981044e-16 -1.10558825e-16  1.15464185e-17  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 1.2877988  -0.6477952   0.65906131]
#  [ 0.71538233 -0.77965957 -0.30148653]
#  [ 0.58479014  0.20224336  0.19003555]]
#
# Inversa com o algórítmo do numpy:
#  [[ 1.2877988  -0.6477952   0.65906131]
#  [ 0.71538233 -0.77965957 -0.30148653]
#  [ 0.58479014  0.20224336  0.19003555]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00 -2.52639151e-16 -1.70942161e-16]
#  [ 6.82912745e-17  1.00000000e+00 -8.88147409e-16]
#  [-3.99987122e-17  1.16711655e-16  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 0.65546191 -0.79116167  0.85088845 -0.552773  ]
#  [-0.44781085 -0.36712452  0.06880095 -0.28394453]
#  [-0.60911783  0.76733806 -0.72553069  1.50167461]
#  [ 1.66550529  0.44713822  1.63771567 -1.75090712]]
#
# Inversa com o algórítmo do numpy:
#  [[ 0.65546191 -0.79116167  0.85088845 -0.552773  ]
#  [-0.44781085 -0.36712452  0.06880095 -0.28394453]
#  [-0.60911783  0.76733806 -0.72553069  1.50167461]
#  [ 1.66550529  0.44713822  1.63771567 -1.75090712]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00  2.49920226e-16  6.07512063e-16 -1.81872001e-16]
#  [ 3.22209470e-17  1.00000000e+00  2.19100148e-16 -8.35827912e-17]
#  [-2.63210775e-16  1.18666992e-15  1.00000000e+00  3.80041751e-16]
#  [ 5.20089623e-17  3.11134008e-17  6.81192203e-16  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 1.21969836  0.56295581 -0.29665327 -1.46246035  0.27383523]
#  [-1.36672103 -0.66605146  0.61445231 -0.03977544  0.78818172]
#  [-0.52544546 -0.36223548 -0.05454051  0.57272053  0.47780749]
#  [ 1.08898804  0.13660345 -0.01549906 -0.48471746 -0.18125018]
#  [-0.22731767 -0.31521927 -0.11788782 -0.45601068 -0.5089699 ]]
#
# Inversa com o algórítmo do numpy:
#  [[ 1.21969836  0.56295581 -0.29665327 -1.46246035  0.27383523]
#  [-1.36672103 -0.66605146  0.61445231 -0.03977544  0.78818172]
#  [-0.52544546 -0.36223548 -0.05454051  0.57272053  0.47780749]
#  [ 1.08898804  0.13660345 -0.01549906 -0.48471746 -0.18125018]
#  [-0.22731767 -0.31521927 -0.11788782 -0.45601068 -0.5089699 ]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00  3.92611211e-17 -1.05705193e-16  7.23012237e-16
#   -2.51018197e-16]
#  [-2.08981643e-16  1.00000000e+00  7.76400311e-16  1.29643792e-15
#   -2.47746627e-16]
#  [-9.67574964e-17  2.56567059e-17  1.00000000e+00 -3.15814606e-17
#    1.42558715e-16]
#  [ 2.56207087e-17  8.71293467e-18 -2.06998635e-16  1.00000000e+00
#   -5.87796367e-17]
#  [ 4.36446180e-17  2.66413218e-17 -3.28587721e-16 -1.41916039e-17
#    1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[-0.18571955 -1.63022316 -0.61522321]
#  [-0.45761394 -0.85859559 -0.03895465]
#  [-1.09783501 -1.62456113 -0.91096855]]
#
# Inversa com o algórítmo do numpy:
#  [[-0.18571955 -1.63022316 -0.61522321]
#  [-0.45761394 -0.85859559 -0.03895465]
#  [-1.09783501 -1.62456113 -0.91096855]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00  1.04712514e-16  1.58518319e-16]
#  [-2.89410604e-17  1.00000000e+00  4.70875313e-17]
#  [-3.08070642e-17 -2.45118061e-16  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[-0.10795754 -0.16360833 -0.89435277]
#  [-0.37048744  0.90278697  0.4208631 ]
#  [ 0.49033343  1.08386301  0.51485247]]
#
# Inversa com o algórítmo do numpy:
#  [[-0.10795754 -0.16360833 -0.89435277]
#  [-0.37048744  0.90278697  0.4208631 ]
#  [ 0.49033343  1.08386301  0.51485247]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00 -2.96425572e-15  1.98901566e-15]
#  [-1.03561073e-17  1.00000000e+00 -4.44661107e-15]
#  [-1.28626977e-16  1.31292067e-14  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[ 1.56463315 -1.36595891]
#  [-0.24435558  1.06236217]]
#
# Inversa com o algórítmo do numpy:
#  [[ 1.56463315 -1.36595891]
#  [-0.24435558  1.06236217]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00 -1.48165980e-16]
#  [-3.13629576e-17  1.00000000e+00]]
#
# Inversa com o algórítmo implementado:
#  [[-1.8013647  -1.53061915  0.11079235]
#  [-0.4276974  -0.31148622 -0.94047963]
#  [-0.91043983 -0.1869241  -0.14469548]]
#
# Inversa com o algórítmo do numpy:
#  [[-1.8013647  -1.53061915  0.11079235]
#  [-0.4276974  -0.31148622 -0.94047963]
#  [-0.91043983 -0.1869241  -0.14469548]]
#
# Multiplicando nossa inversa pela matriz tentando obter a identidade:
#  [[ 1.00000000e+00 -4.30353392e-17  2.47373612e-15]
#  [-2.94112320e-16  1.00000000e+00  9.82430082e-16]
#  [-4.38197918e-17 -5.78785692e-17  1.00000000e+00]]

# %% [markdown]
# Como podemos ver acima, o algoritmo implementado por nós produz resultados basicamente idênticos à função nativa do numpy, e atende a definição de função Inversa. Existem pequenos erros de arredondamento esperados ao se trabalhar com pontos flutuantes que nos impedem de comparar diretamente nossos resultados com os resultados do numpy.
#
# Esses erros surgem devido à forma como as operações com números de pontos flutuantes são realizadas. A maioria das linguagens segue o padrão IEEE 754 para que as operações arritméticas possam ser realizadas utilizando componentes diretos do processador, ganhando muita performance a troco de pequenos erros.
#
# ### Sobre as limitações do métododo:
#
# O método de eliminação de Gauss-Jordan pode ser considerado um método ingênuo pois durante as iterações é possível que venham a ocorrer divisões por zero sem qualquer tipo de verificação, o que leva a um erro onde deveria ter sido possível calcular o inverso da matriz. No nosso código essa divisão pode ocorrer nas linhas:
#
# mat[i] /= mat[i, i] e
#
# mat[k] -= mat[i] * mat[k, i] / mat[i, i]
#
# Caso o elemento em [i, i] (diagonal principal) seja zero. Veja abaixo:

# %%
matriz = np.mat([[0., 5.], [1., 2.]])
inversa(matriz)
# Out:
# <ipython-input-2-b120bf309f14>:21: RuntimeWarning: divide by zero encountered in true_divide
#   mat[i] /= mat[i, i]
# <ipython-input-2-b120bf309f14>:21: RuntimeWarning: invalid value encountered in true_divide
#   mat[i] /= mat[i, i]
# array([[nan, nan],
#        [nan, nan]])

# %% [markdown]
# Veja que o algorítmo do numpy (mais sofisticado) consegue encontrar a inversa dessa matriz sem problemas:

# %%
matriz = np.mat([[0., 5.], [1., 2.]])
np.linalg.inv(matriz)
# Out:
# matrix([[-0.4,  1. ],
#         [ 0.2,  0. ]])
